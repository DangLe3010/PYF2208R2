# %% [markdown]
# ## HÀM VÀ SỬ DỤNG HÀM

# %%
# Khái niệm về module và function:
# Khái niệm về module: Là một file chứa các câu lệnh python và định nghĩa. Module được sử dụng khi làm các chương trình lớn nhằm mục đích chia nhỏ chương trình để dễ dàng quản lý và tổ chức.Module cho phép tái sử dụng.
# Nói cách khác, module chính là thư viện các câu lệnh và định nghĩa. Ví dụ phổ biến nhất mà chúng ta được làm quen từ đầu khóa học là thư viện turtle, và thư viện random.

# %%
# cách gọi module trong python: đầu tiền tạo 1 file mang tên app.py trên máy tính
# import <tên module>
import app
app.tong(5,3)
#LƯU Ý: tên module được đặt theo định dạng giống như của biến, file .py mình có thể đặt tên tùy ý, nhưng nếu đặt không theo định dạng của Python yêu cầu sẽ không thể import đc

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Biến trong module:
#Biến trong module cũng là một dạng của các kiểu dữ liệu trong python(mảng,dict, đối tượng,...)
import app
a = app.dulieu1["ten"]
print(a)
## CHÚ Ý: trong module cũng sẽ tồn tại cả biến cục bộ và biến toàn cục. hãy thử test lại nếu như các bạn đặt biến dulieu1 vào bên dưới phần defined của module app.

# %%
## HÀM VÀ SỬ DỤNG HÀM:
# Nói một cách đơn giản thì module chính là một tập hơn trong đó chứa các hàm, còn các hàm lại chính là một tập hợp con chứa các câu lệnh
# Hàm nhằm giúp cho thực thi một công việc, bài toán nhất định nhỏ hơn, ví dụ như đưa bài toán tính giai thừa của n số tự nhiên, tìm số chẵn lẻ, ...
# Ta có thể hiểu module và hàm theo cách như sơ đồ hình cây trong đó bao gồm thứ tự: Câu lệnh >> hàm >> module
# Điểm mạnh của Hàm hay module chính là ta có thể gọi lại các hàm hay module tại bất kỳ chương trình nào mà ta cần sử dụng
# Hàm và module có điểm chung về cách đặt tên, vì cơ bản nó giống như biến nhưng rộng hơn

# %%
# Lấy ví dụ về Hàm:
def ngay(so_thu):
    """Hàm này dùng để in ra tên của thứ theo tiếng anh khi nhập vào số thứ theo định dạng interger"""
    if so_thu == 1:
        print("Sunday")
    elif so_thu == 2:
        print("Monday")
    elif so_thu == 3:
        print("Tuesday")
    elif so_thu == 4:
        print("Wensday")
    elif so_thu == 5:
        print("Thursday")
    elif so_thu == 6:
        print("Friday")
    elif so_thu == 7:
        print("Saturday")
    else:
        print("Nhập sai giá trị!!!")
ngay(3)
# Out:
# Tuesday

# %%
# hướng dẫn tạo Hàm:
#cú pháp: def < tên hàm>(parameters):
#"""docstring"""
# Statements
# Trong đó:
# def nghĩa là defined là từ khóa bắt buộc phải có nếu muốn tạo hàm
# tên hàm được đặt theo kiểu giống tên biến
# parameters nghĩa là tham số của hàm, có thể có hoặc không
# docstring: hiểu đơn giản là câu mô tả về ý nghĩa của hàm( không bắt buộc có, tuy nhiên nên có để người sử dụng có thể hiểu hơn về hàm)
# dấu : để kết thúc đặt tên hàm
#statements là khối các câu lệnh của hàm

# %%
# sau khi tạo ra hàm thì ta sẽ có thể gọi hàm bằng cách <tên hàm>(parameters)
# hoặc ta có thể gọi docstring bằng cách print(<tên hàm>.__doc__)

# %%
# Hàm nặc danh:
# Hàm nặc danh không được định nghĩa thông thường mà được định nghĩa bằng từ khóa lambda. Nó chỉ chứa một câu lệnh.
# Ví dụ về hàm nặc danh:
add = lambda a,b: a+b
print(add(2,3))
# lưu ý: Hàm ẩn danh hay hàm nặc danh chỉ nên sử dụng đối với một số trường hợp cần sử dụng hàm trong một thời gian ngắn vì nó k thể tái sử dụng
# thường thì hàm nặc danh thường đi với hàm filter() hoặc map()
# Out:
# 5

# %%
# Hàm rỗng: đôi khi ta cần sử dụng hàm nhưng chưa rõ chức năng của nó, và vì thân hàm không được phép để trống, nên ta tạo ra hàm rỗng để tránh phát sinh lỗi trong chương trình

# %% [markdown]
# ## PHẠM VI BIẾN

# %% [markdown]
# ##
#
# Trong Python, cơ bản có hai phạm vi hoạt động chủ yếu của một biến: Biến toàn cục (global), biến cục bộ (local)
#
# Biến toàn cục (Global Variable) là biến được khai báo ngoài phạm vi của hàm
# => có thể được sử dụng mọi nơi,
# => có thể được truy cập bên trong hoặc bên ngoài hàm

# %%
#Ví dụ: Biến toàn cục

x="Hàm và Module 1"
 
def foo():
    print("Trong hàm:", x)
foo()
print("Ngoài hàm:", x)
# Out:
# Trong hàm: Hàm và Module 1
# Ngoài hàm: Hàm và Module 1

# %% [markdown]
# Khi sử dụng biến toàn cục bên trong một hàm thì bạn KHÔNG ĐƯỢC THAY ĐỔI GIÁ TRỊ CHO BIẾN. Như ví dụ dưới đây là sai, bởi vì mình đã thay đổi giá trị cho biến x.

# %%
#Ví dụ: Thay đổi giá trị biến toàn cục

x = 10
 
def foo():
    x = x * 2
    print(x)
foo()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [3], in <cell line: 8>()
#       6     x = x * 2
#       7     print(x)
# ----> 8 foo()
#
# Input In [3], in foo()
#       5 def foo():
# ----> 6     x = x * 2
#       7     print(x)
#
# UnboundLocalError: local variable 'x' referenced before assignment

# %% [markdown]
# ##
# Biến cục bộ (Local Variable): biến được khai báo trong phạm vi của hàm.

# %%
#Ví dụ: Biến cục bộ

def vidu(): 
    y = "Biến cục bộ" 
    print(y) vidu()

# %% [markdown]
# ##
# Từ khóa global: được sử dụng để khai báo một biến cục bộ trong hàm, giúp Python tự hiểu biến đó sẽ trỏ tới một biến cục bộ nằm bên ngoài hàm.

# %%
#Ví dụ: Từ khoá Glogal

x = "global"
 
def foo():
    global x
    y = "local"
    x = x * 2
    print(x)
    print(y)
     
foo()
# Out:
# globalglobal
# local

# %% [markdown]
# ## ĐỐI SỐ

# %%
#Hàm là tập hợp câu lệnh để giải quyết 1 bài toán nhất định


def hieusach():
    print("Nha Nam")
    print("Kim Dong")
    print("ADC book")
    
hieusach()
hieusach()
hieusach()
hieusach()
# Out:
# Nha Nam
# Kim Dong
# ADC book
# Nha Nam
# Kim Dong
# ADC book
# Nha Nam
# Kim Dong
# ADC book
# Nha Nam
# Kim Dong
# ADC book

# %%
#Đối số là: một giá trị (hoặc nhiều giá trị) mà bạn chuyển cho một hàm khi bạn gọi hàm tronf mã.
          #Các đối số cho phép một hàm tạo ra các kết quả khác nhau và làm cho mã có thể tái sử dụng.


#VD1: 

def a(text):
    print(text)

a('Python')
a('Javascript')


#ở đây parameter = text: biến khởi tạo 
#agrument = tham số truyền vào
# Out:
# Python
# Javascript

# %%
#VD2: 

def tiembanh(tentiembanh, diachi, loaibanh):
     print(tentiembanh)
     print(diachi)
     print(loaibanh)

tiembanh('Nguyen Son','30 Ba Trieu','banh mi')
# Out:
# Nguyen Son
# 30 Ba Trieu
# banh mi

# %%
#Khi truyền tham số vào biến trong hàm cần phải truyền đủ
#Nếu truyền tham số vào biến trong hàm mà không đủ tham số thì cần làm như sau:

def python_class(age, text ='kter'):
    print(text)
    print(age)

python_class(70)
# Out:
# kter
# 70

# %% [markdown]
# ## GIÁ TRỊ TRẢ VỀ VÀ GỌI HÀM

# %% [markdown]
# Giới thiệu về lệnh return:
# Hàm có thể có giá trị trả về hoặc không có giá trị trả về. Khi hàm có giá trị trả về, lệnh return được dùng để trả về một giá trị hoặc nhiều giá trị. Khi lệnh return được thực thi, hàm sẽ kết thúc và lệnh return là lệnh không bắt buộc có trong định nghĩa hàm.
# Lệnh return có cú pháp như sau:
#
# return [object]
#
# Trong đó: object là một đối tượng bất kì của một lớp nào đó, có thể là số (number), chuỗi (string), list, tuple, hàm (sẽ biết rõ hơn khi tìm hiểu decorator), lớp (class) hoặc thậm chí là bỏ trống – trường hợp bỏ trống thì object return về được tính là None

# %%
#Ví dụ lệnh return

def calculator(a, b):
    sum = a + b
    return sum
print(sum)
# Out:
# <built-in function sum>

# %%
#Ví dụ lệnh return 2

def square(x):
    y = x*x
print(square(4))
#Output 
None
# Out:
# None

# %% [markdown]
# Khi chạy lệnh "print square(4)", chương trình sẽ in ra kết quả trả về của hàm square, nhưng do chúng ta không khai báo giá trị trả về trong hàm nên kết quả in ra là “None”.

# %%
#Ví dụ

def square(x):
    return  x*x
print(square(4))

#Khi  gọi hàm “return” và thực thi mã nguồn, chương trình sẽ trả về giá trị “16”.
# Out:
# 16

# %% [markdown]
# Hàm trả về nhiều giá trị:
# Có thể sử dụng một lệnh return để trả về nhiều giá trị từ một hàm

# %%
#Ví dụ

def calculator(a, b):
    summ = a + b
    sub = a - b
    mul = a * b
    return summ, sub, mul
print(summ, sub, mul)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#       6     mul = a * b
#       7     return summ, sub, mul
# ----> 8 print(summ, sub, mul)
#
# NameError: name 'summ' is not defined

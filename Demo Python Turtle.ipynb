# %% [markdown]
# # TÌM HIỂU THƯ VIỆN TURTLE
# 1. Sử dụng lệnh PIP
# 2. Thư viện Turtle
# 3. Điều khiển chuyển động trong turle
# 4. Điều khiển nét bút trong turtle

# %% [markdown]
# ## LỆNH PIP
# PIP là một trình quản lý gói cho Python, cho phép cài đặt và
# quản lý các thư viện và dependency mà không được phân
# phối như một phần của thư viện chuẩn của Python.
# > pip command

# %% [markdown]
# Để kiểm tra pip đang chạy trên máy tính, chúng ta có thể sử dụng command:

# %%
! pip --version
# Out:
# pip 22.2.2 from C:\Users\dangl\AppData\Local\Programs\Python\Python310\lib\site-packages\pip (python 3.10)

# %%
! pip install turtle
# Out:
# Collecting turtle
#   Using cached turtle-0.0.2.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [7 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\dangl\AppData\Local\Temp\pip-install-setypotx\turtle_b650c28fef3747d8a25400d52213c681\setup.py", line 40
#       except ValueError, ve:
#              ^^^^^^^^^^^^^^
#   SyntaxError: multiple exception types must be parenthesized
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# # THƯ VIỆN TURLTE
# - Turtle graphic là một chương trình con có sẵn trong python khi bạn đã cài Python lên máy
# - Turtle được xem như một cây bút vẽ, di chuyển đến đâu là vẽ hình đến đó

# %% [markdown]
# ### Cài đặt thư viện turtle với pip

# %% [markdown]
# ### Sử dụng turtle

# %% [markdown]
# Bước 1: Import module turtle

# %%
import turtle

# %% [markdown]
# Bước 2: Tạo đối tượng turtle

# %%
pen = turtle.Turtle()

# %% [markdown]
# Bước 3: Vẽ bằng các phương thức của turtle

# %%
pen.backward(150)
## forward, backward, left, right

# %% [markdown]
# Bước 4: Hoàn thành vẽ

# %%
turtle.done()

# %% [markdown]
# ### Thực hành: Vẽ hình vuông

# %%
import turtle
pen = turtle.Turtle()
pen.forward(150)
pen.right(90)
pen.forward(150)
pen.right(90)
pen.forward(150)
pen.right(90)
pen.forward(150)
turtle.done()

# %% [markdown]
# ### Thực hành: Vẽ hình tam giác đều

# %%
import turtle
pen = turtle.Turtle()
pen.forward(150)
pen.right(120)
pen.forward(150)
pen.right(120)
pen.forward(150)
turtle.done()

# %% [markdown]
# ### Các lệnh điều khiển nét bút

# %% [markdown]
# Thay đổi kích thước của bút

# %%
import turtle
pen = turtle.Turtle()
pen.pensize(19)
pen.forward(50)

# %% [markdown]
# Nhấc bút lên

# %%
pen.penup()
pen.forward(200)

# %% [markdown]
# Đặt bút xuống

# %%
pen.pendown()
pen.forward(150)

# %% [markdown]
# ### Điều chỉnh màu sắc trong turtle

# %% [markdown]
# Thay đổi màu rùa

# %%
pen.right(60)
pen.pencolor("red")
pen.forward(100)

# %% [markdown]
# Thay đổi màu bút

# %%
pen.fillcolor("orange")

# %% [markdown]
# Thay đổi tốc độ

# %%
pen.speed(10)
pen.right(90)
pen.forward(100)
